# %%
import pickle
    
with open('input_norm_train_accuracy.pkl', 'rb') as f:
    input_norm_train_accuracy = pickle.load(f)
with open('input_norm_test_accuracy.pkl', 'rb') as f:
    input_norm_test_accuracy = pickle.load(f)
    
with open('norm_train_accuracy.pkl', 'rb') as f:
    norm_train_accuracy = pickle.load(f)
with open('norm_test_accuracy.pkl', 'rb') as f:
    norm_test_accuracy = pickle.load(f)
    
with open('prenorm_train_accuracy.pkl', 'rb') as f:
    prenorm_train_accuracy = pickle.load(f)
with open('prenorm_test_accuracy.pkl', 'rb') as f:
    prenorm_test_accuracy = pickle.load(f)
    
with open('original_train_accuracy.pkl', 'rb') as f:
    original_train_accuracy = pickle.load(f)
with open('original_test_accuracy.pkl', 'rb') as f:
    original_test_accuracy = pickle.load(f)

with open('zero_masked_train_accuracy.pkl', 'rb') as f:
    zero_masked_train_accuracy = pickle.load(f)
with open('zero_masked_test_accuracy.pkl', 'rb') as f:
    zero_masked_test_accuracy = pickle.load(f)
    
with open('weighted1_train_accuracy.pkl', 'rb') as f:
    weighted1_train_accuracy = pickle.load(f)
with open('weighted1_test_accuracy.pkl', 'rb') as f:
    weighted1_test_accuracy = pickle.load(f)
    
with open('RLPE_train_accuracy.pkl', 'rb') as f:
    RLPE_train_accuracy = pickle.load(f)
with open('RLPE_test_accuracy.pkl', 'rb') as f:
    RLPE_test_accuracy = pickle.load(f)
    
with open('scaling_RLPE_train_accuracy.pkl', 'rb') as f:
    scaling_RLPE_train_accuracy = pickle.load(f)
with open('scaling_RLPE_test_accuracy.pkl', 'rb') as f:
    scaling_RLPE_test_accuracy = pickle.load(f)
    
with open('Enhanced_train_accuracy.pkl', 'rb') as f:
    Enhanced_train_accuracy = pickle.load(f)
with open('Enhanced_test_accuracy.pkl', 'rb') as f:
    Enhanced_test_accuracy = pickle.load(f)

# %%
input_norm_train_accuracy = [i.item() for i in input_norm_train_accuracy]
input_norm_test_accuracy = [i.item() for i in input_norm_test_accuracy]

norm_train_accuracy = [i.item() for i in norm_train_accuracy]
norm_test_accuracy = [i.item() for i in norm_test_accuracy]

# prenorm_train_accuracy = [i.item() for i in prenorm_train_accuracy]
# prenorm_test_accuracy = [i.item() for i in prenorm_test_accuracy]

original_train_accuracy = [i.item() for i in original_train_accuracy]
original_test_accuracy = [i.item() for i in original_test_accuracy]

zero_masked_train_accuracy = [i.item() for i in zero_masked_train_accuracy]
zero_masked_test_accuracy = [i.item() for i in zero_masked_test_accuracy]

weighted1_train_accuracy = [i.item() for i in weighted1_train_accuracy]
weighted1_test_accuracy = [i.item() for i in weighted1_test_accuracy]

RLPE_train_accuracy = [i.item() for i in RLPE_train_accuracy]
RLPE_test_accuracy = [i.item() for i in RLPE_test_accuracy]

scaling_RLPE_train_accuracy = [i.item() for i in scaling_RLPE_train_accuracy]
scaling_RLPE_test_accuracy = [i.item() for i in scaling_RLPE_test_accuracy]

Enhanced_train_accuracy = [i.item() for i in Enhanced_train_accuracy]
Enhanced_test_accuracy = [i.item() for i in Enhanced_test_accuracy]

# %%
from matplotlib import pyplot as plt

x = [i for i in range(20)]

# plt.plot(x, input_norm_test_accuracy, label="input_norm_test_accuracy")
# plt.plot(x, norm_test_accuracy, label="norm_test_accuracy")
plt.plot(prenorm_test_accuracy, label="prenorm_test_accuracy")
plt.plot(original_test_accuracy, label="original_test_accuracy")
plt.plot(zero_masked_test_accuracy, label="zero_masked_test_accuracy")
plt.plot(weighted1_test_accuracy, label="weighted1_test_accuracy")
plt.plot(RLPE_test_accuracy, label="RLPE_test_accuracy")
plt.plot(scaling_RLPE_test_accuracy, label="scaling_RLPE_test_accuracy")
plt.plot(Enhanced_test_accuracy, label="Enhanced_test_accuracy")
plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('matplotlib sample')
plt.show()
