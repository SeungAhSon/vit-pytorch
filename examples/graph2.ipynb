# %%
import pickle
    
with open('zero_masked_test_accuracy100.pkl', 'rb') as f:
    zero_masked_test_accuracy100 = pickle.load(f)
    
with open('weighted1_test_accuracy100.pkl', 'rb') as f:
    weighted1_test_accuracy100 = pickle.load(f)

# %%
zero_masked_test_accuracy100 = [i.item() for i in zero_masked_test_accuracy100]
weighted1_test_accuracy100 = [i.item() for i in weighted1_test_accuracy100]

# %%
from matplotlib import pyplot as plt

x = [i for i in range(100)]
y = [i for i in range(100)]

plt.plot(zero_masked_test_accuracy100, label="prenorm_test_accuracy")
plt.plot(weighted1_test_accuracy100, label="weighted1_test_accuracy100")

plt.legend()
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('matplotlib sample')
plt.show()
